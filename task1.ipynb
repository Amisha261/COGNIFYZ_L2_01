# %% [markdown]
# # Restaurant Ratings

# %% [markdown]
# ## 1. Importing necassary python libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Dataset .csv")

# %%
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
data.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
data.columns = data.columns.str.strip()

# %%
data.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
data[["Aggregate rating","Votes"]].isnull().sum()
# Out:
# Aggregate rating    0
# Votes               0
# dtype: int64

# %%
plt.figure(figsize=(10, 6))
data['Aggregate rating'].hist(bins=20, color='skyblue')
plt.title('Distribution of Aggregate Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
common_rating=data["Aggregate rating"].idxmax()
common_rating
# Out:
# 3

# %%
average_vote=data["Votes"].idxmax()
average_vote
# Out:
# 728

# %% [markdown]
# ## SUMMARY

# %% [markdown]
# Load the Dataset:
#
# - Load the dataset containing the restaurant data into your analysis environment (e.g., Python).
#
# Inspect the Dataset:
#
# - Inspect the dataset to understand its structure and identify the columns that contain the rating and vote information.
#
# Analyze the Distribution of Aggregate Ratings:
#
# - Use a histogram or bar chart to visualize the distribution of ratings.
#
# Determine the Most Common Rating Range:
#
# - Identify the rating range that appears most frequently.
#
# Calculate the Average Number of Votes:
#
# - Calculate the average number of votes received by restaurants.
#
# Histogram of Ratings:
#
# - The histogram will show the distribution of ratings, with the x-axis representing the rating values and the y-axis representing the frequency of each rating.
